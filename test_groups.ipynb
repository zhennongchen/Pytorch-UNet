# %%
from utils.dataset import CrossValDataset
from os import listdir

# %%
groupPath = "D:\\autoseg\\train"

traindataset = CrossValDataset(groupPath,2, testFlag = False)
testdataset  = CrossValDataset(groupPath,2, testFlag = True)

for ii in range(100):
    groupMatch,groupIndex = traindataset.globalToGroupIndex(ii)
    print("Train -- i: " + str(ii) + ", g: " + str(groupMatch) + ", j: " + str(groupIndex))
    
    groupMatch,groupIndex = testdataset.globalToGroupIndex(ii)
    print("Test  -- i: " + str(ii) + ", g: " + str(groupMatch) + ", j: " + str(groupIndex))
#     item = dataset.__getitem__(ii)
#     print(item)


# numPartition = 5
# for partition in range(numPartition):
#     trainDataSet = CrossValDataset(groupPath,partition, testFlag = False)
#     testDataSet =  CrossValDataset(groupPath,partition, testFlag = True)
# Out:
# Indexing data directory: D:\autoseg\train...
# 5 groups found.
# Partition selected: 2
# Serving training data.
# Indexing data directory: D:\autoseg\train...
# 5 groups found.
# Partition selected: 2
# Serving test data.
# Train -- i: 0, g: 0, j: 0
# Test  -- i: 0, g: 2, j: 0
# Train -- i: 1, g: 0, j: 1
# Test  -- i: 1, g: 2, j: 1
# Train -- i: 2, g: 0, j: 2
# Test  -- i: 2, g: 2, j: 2
# Train -- i: 3, g: 0, j: 3
# Test  -- i: 3, g: 2, j: 3
# Train -- i: 4, g: 0, j: 4
# Test  -- i: 4, g: 2, j: 4
# Train -- i: 5, g: 0, j: 5
# Test  -- i: 5, g: 2, j: 5
# Train -- i: 6, g: 0, j: 6
# Test  -- i: 6, g: 2, j: 6
# Train -- i: 7, g: 0, j: 7
# Test  -- i: 7, g: 2, j: 7
# Train -- i: 8, g: 0, j: 8
# Test  -- i: 8, g: 2, j: 8
# Train -- i: 9, g: 0, j: 9
# Test  -- i: 9, g: 2, j: 9
# Train -- i: 10, g: 0, j: 10
# Test  -- i: 10, g: 2, j: 10
# Train -- i: 11, g: 0, j: 11
# Test  -- i: 11, g: 2, j: 11
# Train -- i: 12, g: 0, j: 12
# Test  -- i: 12, g: 2, j: 12
# Train -- i: 13, g: 0, j: 13
# ...

# %%
listdir('D:\\autoseg\\train\\group_05')
